# %% [markdown]
# # An Introduction to Text Mining with Python

# %% [markdown]
# ## Introduction

# %% [markdown]
# This workshop does not require any coding experience. However, you may run into some basic errors here and there. Don't worry too much! This is completely normal and just part of the coding experience 😁

# %% [markdown]
# ### Roadmap
# During this workshop we will:
# * Learn the basic components of text mining
# * Practice and examine simple data mining tools
# * Tokenize and parse data using the Natural Language Toolkit
# * Conduct text sentiment analysis

# %% [markdown]
# ### Resources:
# * Voyant Tools (https://voyant-tools.org/)
# * Penbank Reference Guide (https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html)

# %% [markdown]
# ### Getting Started with Simple Text Mining using Voyant Tools

# %% [markdown]
# I came across through Yale's resources for text mining (see 'Additional Helpful Links' section), and it's great for coders and non-coders. Voyant Tools is an open-source software used to perform textual analysis, particularly aimed at scholars in the digital humanities. It's a useful resource for visualization and conducting basic text mining analysis.

# %% [markdown]
# __To get started, go to the link: https://voyant-tools.org/. Start by pasting one of the following HTML links into the Voyant Box and click the "Reveal" button:__
# <br>
# * Zora Neale Hurston's Excerpt of _Their Eyes Were Watching God_ (http://xroads.virginia.edu/~DRBR/hurston_god.html)
# * Shakesphere's Romeo and Juliet (https://shakespeare.mit.edu/romeo_juliet/full.html)
# * US Immigration and Custom's Enforcement website on "About Us"(https://www.ice.gov/mission)
# * Your own site of choosing!
#
# ![Screenshot 2023-10-13 at 6.40.33 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-10-13 at 6.47.49 AM.png](data:image/png;base64,...)

# %% [markdown]
# #### Some Tools and Features of Voyant Tools
#
# __Wordclouds__: Wordclouds (top left) are often used in text mining analysis to more a graphical representation of the most prominent words (sorted by frequency) in a text.
#
# __Concordance__: Like we went through on the presentation, Voyant tools provides you (on the bottom right) with the context of major words that appear.
#
# __Correlation__: This is one of my favorite tools. The site can show us the correlation between two words. For example, you can see the correlation between "immigrant" and "criminal" on ICE's website. These observations can point to something about rhetoric, the construction of stereotypes through linguistics, and creating ideological correlations between two categories (i.e. terrorist/Islam, undocumented/criminal, etc.).

# %% [markdown]
# __For those that have a further understanding of HTML, you may choose to modify the input using the "options tool"__
#
# You can "inspect element" using Google Chrome on the original HTML pages, and find a specific piece of metadata you wish to modify.

# %% [markdown]
# ![Screenshot 2023-10-13 at 7.07.36 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-10-13 at 7.08.12 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Getting Started with the NLTK Toolkit

# %% [markdown]
# Now, we are going to move to using the NLTK Toolkit with Python. This is a popular package used by those in the digital humanities/computational linguistics, as it provides the ability to analyze, classify, tag linguistic data. The documentation guide is listed in the "Additional Helpful Links" section for those that want to examine the package more closely.

# %%
#import packages
import nltk
from nltk.corpus import treebank

# %% [markdown]
# Next, we are going to create a variable named "sentence" as our input into the word tokenizer. You may choose your own sentence, or one of the following sentences:
# * At eight o'clock on Thursday morning ... Arthur didn't feel very good. (PROVIDED BY NLTK PACKAGE)
# * The curious cat pounced on a shiny red ball in the garden.
# * She sipped her steaming coffee, lost in thought as the rain tapped on the window.
# * The aroma of freshly baked bread wafted through the neighborhood, making everyone hungry.
#
# _NOTE: I used ChatGPT to make these sentences, in case you were wondering why they were a bit weird 😂_
#
# Once you have chosen your sentence, input the sentence into the middle of the quotes. Here, you may observer that we are using the tokenizer function, we will be using three sets of double quotes on both sides.

# %%
sentence = """At eight o'clock on Thursday morning
... Arthur didn't feel very good."""

# %%
#Tokenize the sentence. This function will separate the sentence into separate words.
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
#Now, we will use the pos-tag function to categorize each word grammatically.
tagged = nltk.pos_tag(tokens)
print(tagged)
# Out:
# [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), ('Arthur', 'NNP'), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')]

# %% [markdown]
# The abbreviations are in accordance to the Penn Treebank Project guide, which can be found here: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %% [markdown]
# Now, we can use the "chunk" function to categorize our words into segments.

# %%
entities = nltk.chunk.ne_chunk(tagged)
print(entities)
# Out:
# (S
#   At/IN
#   eight/CD
#   o'clock/NN
#   on/IN
#   Thursday/NNP
#   morning/NN
#   (PERSON Arthur/NNP)
#   did/VBD
#   n't/RB
#   feel/VB
#   very/RB
#   good/JJ
#   ./.)

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# Sentiment analysis is a natural language processing (NLP) technique used to determine the overall emotional tone or sentiment expressed in a piece of text. It involves classifying a subtext as positive, negative, or neutral by assigning numerical scores to indicate the degree to which a text is positive or negative. We can use sentiment analysis
#
# Sentiment analysis, also known as opinion mining, is a natural language processing (NLP) technique used to determine the emotional tone or sentiment expressed in a piece of text, such as a tweet, review, or news article. It involves analyzing the text to classify it as positive, negative, or neutral, or to assign a numerical score indicating the degree of positivity or negativity. Sentiment analysis has a wide range of applications, from social media monitoring to market research and customer feedback analysis.
#
# Digital humanity students can use sentiment analysis to consider how the certain texts' affect constructs and/or reifies historical, social, and geo-political entanglements of power. For this workshop, we will be looking at Donald Trump's tweets related to immigration from 2020 and prior.

# %% [markdown]
# ## Getting Started: Converting Tweets into a List

# %% [markdown]
# __Donald Trump's Tweets__
#
# I have uploaded a .csv file that contains approx 1.6K of Donald Trump's tweets related to immigration, undocumented migrants, and borders. We are going to first start important this .csv file and convert it into a pandas dataframe. To get started, download the .csv file and have it located in your "Downloads" or "Desktop" or "Documents" folder, whichever is easiest.
#
# __If you run into issues with this, you don't need to worry. In a couple of steps down, I have set a variable that you can use in the case where you cannot get the .csv file to upload properly__.

# %%
#import packages + pandas
import pandas as pd

# %% [markdown]
# This can be a bit tricky, but you want to find out the address of where your .csv has downloaded. On Macs, you can do this by __going to the top and clicking View < View Path.__ This will then show you your path __at the bottom of the Finder Folder.__

# %% [markdown]
# ![Screenshot 2023-10-13 at 9.57.29 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-10-13 at 9.58.20 AM.png](data:image/png;base64,...)

# %% [markdown]
# For Windows, you may just look at the address bar.
# <br>
# <br>
# I took this screenshot from a WikiHow page found here: https://www.wikihow.com/Find-a-File%27s-Path-on-Windows if you are still stuck.
# <br>
# <br>

# %% [markdown]
# ![Screenshot 2023-10-13 at 10.01.06 AM.png](data:image/png;base64,...)

# %%
#We want to take the location of our document and place it in between the parenthesis of the function.

#uploads csv file from your downloads
spreadsheet = pd.read_csv('/Users/rukimani/Downloads/trump_tweets.csv')

# %%
#prints the first 5 lines of the csv
spreadsheet.head()
# Out:
#                source                                               text  \
# 0  Twitter Web Client  Congratulations to Miss Mexico Jimena Navarret...
# 1  Twitter Web Client  If only @Obama was as focused on balancing the...
# 2           TweetDeck  @BarackObama has sold guns to Mexican drug lor...
# 3           TweetDeck  China's business interests reach far and wide-...
# 4           TweetDeck  Fast and Furious put semi-automatics in the ha...
#
#       created_at  retweet_count  favorite_count is_retweet        id_str
# 0  8/24/10 14:07            193              32      False  2.200311e+10
# 1   7/7/11 16:20            400              80      False  8.900000e+16
# 2  7/18/11 16:21            100              11      False  9.300000e+16
# 3  8/30/11 19:54            100              12      False  1.090000e+17
# 4   9/2/11 18:27            209              29      False  1.100000e+17

# %% [markdown]
# Now, we are going to go through and take each tweet in the column "text" and put it together as a list.

# %%
#takes the column and converts it into a list
tweets = spreadsheet['text'].values.tolist()

# %%
#prints tweets
print(tweets)
# Out:
# ['Congratulations to Miss Mexico Jimena Navarrete our new Miss Universe 2010 and congratulations to everyone for a fantastic show.', "If only @Obama was as focused on balancing the budget as he is on weakening Israel's borders then America would be on the path to solvency.", '@BarackObama has sold guns to Mexican drug lords while his DOJ erodes our 2nd  Amendment rights.', "China's business interests reach far and wide---even domestically within our borders. We need to reassess our relationship.", 'Fast and Furious put semi-automatics in the hands of Mexican drug lords that killed Americans - @BarackObama should answer all questions.', 'Why was @BarackObama selling guns to Mexican drug dealers?', "Third Gun Linked to 'Fast and Furious' Identified at Border Agent's Murder Scene. When will the White House come clean?", 'It seems @BarackObama had our tax dollars buy guns for Mexican drug lords that were used to kill Americans. We need answers now.', '@BarackObama sold guns to the Mexica
# ...

# %% [markdown]
# __If you ran into issues with the list of tweets, you can use this variable going forward. Just make sure to put "tweets_substitute" everywhere there is the word "tweets."__

# %%
tweets_substitute = ['Congratulations to Miss Mexico Jimena Navarrete our new Miss Universe 2010 and congratulations to everyone for a fantastic show.', "If only @Obama was as focused on balancing the budget as he is on weakening Israel's borders then America would be on the path to solvency.", '@BarackObama has sold guns to Mexican drug lords while his DOJ erodes our 2nd  Amendment rights.', "China's business interests reach far and wide---even domestically within our borders. We need to reassess our relationship.", 'Fast and Furious put semi-automatics in the hands of Mexican drug lords that killed Americans - @BarackObama should answer all questions.', 'Why was @BarackObama selling guns to Mexican drug dealers?', "Third Gun Linked to 'Fast and Furious' Identified at Border Agent's Murder Scene. When will the White House come clean?", 'It seems @BarackObama had our tax dollars buy guns for Mexican drug lords that were used to kill Americans. We need answers now.', '@BarackObama sold guns to the Mexican drug cartels.  They were used in the murders of Americans . Where is the outrage?', 'Illegal immigration is a wrecking ball aimed at US taxpayers. Washington needs to get tough and fight for "WÉ (cont) http://t.co/tblJ9PWm', "Canada's legal immigration plan starts with a simple and smart question: How will any immigrant applying foÉ (cont) http://t.co/aHYaJt5b", 'ObamaCare gives free insurance to illegal immigrants. Yet @BarackObama is cutting our troops healthcare.  (cont) http://t.co/SHQuYovw', 'The illegal immigrant crime problem is far more serious and threatening than most people understand. Along our (cont) http://t.co/UAAIAKdS,03-15-2012 13:29:09,86,29,false,180284502147469312\nTwitter Web Client,My @foxandfriends interview discussing @BarackObama\'s reckless spending the Buffet Tax gimmick and #CelebApprentice http://t.co/Bco0a2AD,04-16-2012 21:21:59,49,17,false,191999907375235072\nTwitLonger Beta,Don\'t be fooled. In 2008 @BarackObama promised immigration reform in his 1st yr of his 1st term. Now promising (cont) http://t.co/uQKNoHhv,04-19-2012 20:12:14,97,17,false,193069515729412096\nTwitter Web Client,Today\'s announcement by @BarackObama on immigration was done for reelection. He is using the office of the presidency as a campaign tool.,06-15-2012 18:24:42,360,40,false,213698564335996928\nTwitter Web Client,The Amateur! First @BarackObama was caught bowing to the Saudi King but now the President of Mexico!  http://t.co/f0CFiUS9,06-20-2012 19:36:33,139,26,false,215528582670331906\nTwitter Web Client,The Euro is going to collapse soon. Cross border lending is already down and banks are stopping their Euro investments.,08-14-2012 20:19:16,409,53,false,235470665422106624\nTwitter Web Client,Putin just sent a Russian nuclear sub to the Gulf of Mexico. @BarackObama can\'t be bothered he is too concerned with @MittRomney\'s taxes.,08-22-2012 18:52:05,701,95,false,238347828592771075\nTwitter Web Client,Major Mexican cartel boss El Diego was just arrested with weapons provided to him through Fast and Furious http://t.co/rFLwJBxy   Media??,10-03-2012 13:22:04,306,33,false,253485069983956992\nTwitter Web Client,Obama weak on immigration. All words no action. He\'s been Prez 4 years.,10-17-2012 02:12:13,871,210,false,258389924456312832\nTwitter Web Client,Pageant people are really talking about Venezuela Brazil Mexico USA India Australia.,12-19-2012 17:09:56,414,68,false,281446278523662336\nTwitter Web Client,The Republicans must face reality &amp; create a strong &amp; positive immigration policy--if not they will continue to lose elections.,01-02-2013 18:27:12,232,102,false,286539154005835776\nTwitter Web Client,The Republicans will get zero credit for passing immigration reformŃand I said zero!,01-30-2013 15:47:33,172,91,false,296645836270612482\nTwitter Web Client,Immigration reform is fineŃbut donŐt rush to give away our country! Sounds like thatŐs whatŐs happening.,01-30-2013 15:48:05,273,176,false,296645971331411968\nTwitter Web Client,Again immigration reform is fineŃbut donŐt rush to give away our country. ThatŐs whatŐs happening!,02-06-2013 14:48:31,140,68,false,299167694069047296\nTwitter Web Client,Re: immigration. Do the Republicans not realize that Dems will get 100% of 11 million votes no matter what they do?,02-06-2013 14:48:57,200,137,false,299167805603971072\nTwitter Web Client,Immigration reform really changes the voting scales for the RepublicansŃfor the worse!,02-06-2013 14:49:26,147,127,false,299167924676091904\nTwitter Web Client,Just as I predicted immigration reform will increase the cost of ObamaCare over $300B http://t.co/CmDQ20a2 More money borrowed from China.,02-06-2013 19:45:20,449,198,false,299242390244438016\nTwitter Web Client,.@GOP need to face reality Đ not one of the illegal immigrants granted amnesty will vote Republican.,02-14-2013 20:39:05,306,290,false,302155020697235456\nTwitter Web Client,No surprise with the talk of amnesty in DC illegal immigration is picking up in Arizona http://t.co/eYAeRve4,02-14-2013 21:24:05,168,93,false,302166344269455360\nTwitter Web Client,John McCain had a really hard time with his town hall meeting on immigration. They really went after him!,02-21-2013 16:01:30,40,25,false,304621882139885568\nTwitter Web Client,Republicans must be careful with immigrationŃdonŐt give our country away.,02-21-2013 16:02:50,450,389,false,304622217185095681\nTwitter Web Client,Congrats to @JimmieJohnson a great guy on winning Daytona!,02-24-2013 23:56:33,136,53,false,305828595719364609\nTwitter for Android,@JimmieJScott: @realDonaldTrump Did you ever think #TheApprentice would be the ratings machine it is for so long?" No but who ever knows.', 'CPAC 2013: Donald Trump: Immigration reform is a Ôsuicide missionŐ for GOP http://t.co/WdMLJcXZLL by @SethMcLaughlin1']

# %% [markdown]
# ### Sentiment Analysis
#
# Now that we have our tweets in a list, we will do some basic sentiment analysis on our tweets. We will need to import some additional packages.

# %%
#import more packages
from tweepy import OAuthHandler
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Define values
sentiment_values = [TextBlob(tweet) for tweet in tweets]

#IF YOU ARE USING TWEETS_SUBSTITUTE -> your code should be this instead
#sentiment_values = [TextBlob(tweet) for tweet in tweets_substitute]

# %%
# Find the polarity values for each tweet -> .sentiment.polarity is the method that finds the polarity value in TextBlob
polarity_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_values]

# %% [markdown]
# ### Polarity Values
#
# The polarity value for sentiment analysis is a numerical value that represents the sentiment or emotion associated with a piece of text. The polarity value is a float number within the range of -1 to 1, where:
# - A positive polarity value (close to 1) indicates a positive sentiment, meaning the text is positive, happy, or favorable.
# - A negative polarity value (close to -1) indicates a negative sentiment, meaning the text is negative, unhappy, or unfavorable.
# - A polarity value around 0 suggests a neutral sentiment, indicating that the text is neither positive nor negative, or it's a mix of bot

# %%
#Print the first value to examine a bit closer
polarity_values[0]
# Out:
# [0.2681818181818182,
#  'Congratulations to Miss Mexico Jimena Navarrete our new Miss Universe 2010 and congratulations to everyone for a fantastic show.']

# %%
# Print all values
polarity_values[0:99]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67f0518e32c1> in <cell line: 2>()
#       1 # Print all values
# ----> 2 polarity_values[0:99]
#
# NameError: name 'polarity_values' is not defined

# %% [markdown]
# Now, let's make a pandas dataframe that shows our tweets and their polarity.

# %%
polarity_df = pd.DataFrame(polarity_values, columns=["polarity", "tweet"])

#display the first 20 entries (b/c we have over 1000 entries) -> if you used tweets_substitute, you should get 13 values
polarity_df.head(20)
# Out:
#     polarity                                              tweet
# 0   0.268182  Congratulations to Miss Mexico Jimena Navarret...
# 1   0.000000  If only @Obama was as focused on balancing the...
# 2   0.000000  @BarackObama has sold guns to Mexican drug lor...
# 3   0.100000  China's business interests reach far and wide-...
# 4   0.000000  Fast and Furious put semi-automatics in the ha...
# 5   0.000000  Why was @BarackObama selling guns to Mexican d...
# 6   0.141667  Third Gun Linked to 'Fast and Furious' Identif...
# 7   0.000000  It seems @BarackObama had our tax dollars buy ...
# 8   0.000000  @BarackObama sold guns to the Mexican drug car...
# 9  -0.444444  Illegal immigration is a wrecking ball aimed a...
# 10  0.138095  Canada's legal immigration plan starts with a ...
# 11 -0.233333  ObamaCare gives free insurance to illegal immi...
# 12  0.062924  The illegal immigrant crime problem is far mor...
# 13  0.000000  CPAC 2013: Donald Trump: Immigration reform is...
# ...

# %% [markdown]
# ### Let's create a wordcloud!

# %%
# Create a Wordcloud from the tweets
tweets = ' '.join([text for text in tweets])
wordcloud = WordCloud(width=1400, height=1000, max_font_size=110).generate(tweets)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Let's make a pie chart!

# %%
#First, let's count the number of positive, neutral, and negative polarities there are in our list of tweets based on 1, 0, and -1

#get all the polarity values
polarity_vals =polarity_df["polarity"]

positive = 0
neutral = 0
negative = 0

for polarity in polarity_vals:
    if polarity > 0:
        positive +=1
    if polarity < 0:
        negative += 1
    if polarity == 0:
        neutral += 1

# %%
polarity_categories = ['Positive', 'Neutral', 'Negative']
polarity_counts = [positive, neutral, negative]

plt.pie(polarity_counts, labels=polarity_categories, autopct='%1.1f%%', startangle=140)
plt.title("Polarity Distribution")

plt.show()

# %% [markdown]
# # Let's make a bar chart!

# %%
sentiment_categories = ['Positive', 'Neutral', 'Negative']
counts = [positive, negative, neutral]  # Replace with the actual counts for each category

plt.bar(sentiment_categories, counts, color=['green', 'blue', 'red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment Categories')
plt.ylabel('Counts')

plt.show()

# %% [markdown]
# ### Additional Helpful Links
# * The NLTK Package if you're interested in exploring more functions: __https://www.nltk.org/__
# * Yale DH has some additional data mining + graphing practice that are easy-to-follow: __https://guides.library.yale.edu/tdm/practice__
# * This is a great reading if you want to think more about affect theory and analysis within the framework of black/colonial studies: __Deb Thomas' "Introduction" in _Humanness in the Wake of the Plantation___

# %% [markdown]
# ### Citations
#
# Bird, Steven, Edward Loper and Ewan Klein (2009), Natural Language Processing with Python. O’Reilly Media Inc.
#
# THOMAS, D. A. (2019). Introduction: HUMANNESS in the WAKE of the PLANTATION. In Political Life in the Wake of the Plantation: Sovereignty, Witnessing, Repair (pp. 1–21). Duke University Press. https://doi.org/10.2307/j.ctv11cw0dc.4
#
# Silaparasetty, N. (2022, May 26). Twitter sentiment analysis for data science using python in 2022. Medium. https://medium.com/@nikitasilaparasetty/twitter-sentiment-analysis-for-data-science-using-python-in-2022-6d5e43f6fa6e
#
# Yale University Library Research Guides: Resources for text and data mining: Practice text or Data Mining. Home - Yale University Library Research Guides at Yale University. (n.d.). https://guides.library.yale.edu/tdm/practice
#
# WikiHow. (n.d.). Find a File's Path on Windows. WikiHow. https://www.wikihow.com/Find-a-File%27s-Path-on-Windows
